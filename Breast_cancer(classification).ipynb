# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitahegde-30/HarshitaHegde/blob/main/Breast_cancer(classification).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
bc = pd.read_csv('/content/drive/MyDrive/data_class.csv')
bc
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
bc.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
x = bc.iloc[:,2:-1]
x
# Out:
#      texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0           10.38          122.80     1001.0          0.11840
# 1           17.77          132.90     1326.0          0.08474
# 2           21.25          130.00     1203.0          0.10960
# 3           20.38           77.58      386.1          0.14250
# 4           14.34          135.10     1297.0          0.10030
# ..            ...             ...        ...              ...
# 564         22.39          142.00     1479.0          0.11100
# 565         28.25          131.20     1261.0          0.09780
# 566         28.08          108.30      858.1          0.08455
# 567         29.33          140.10     1265.0          0.11780
# 568         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# ...

# %%
y = bc.iloc[:,0]
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state=40)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# **Logistic** **Regression**

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[113,   2],
#        [  2,  54]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_true=y_train, y_pred=classifier.predict(x_train))*100
# Out:
# 98.74371859296483

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[113   2]
#  [  2  54]]
#               precision    recall  f1-score   support
#
#            B       0.98      0.98      0.98       115
#            M       0.96      0.96      0.96        56
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# **K**-**NN**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_classifier = KNeighborsClassifier(n_neighbors=5)
print(knn_classifier)
# Out:
# KNeighborsClassifier()

# %%
knn_classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_classifier_predictions = knn_classifier.predict(x_test)
knn_classifier_predictions
# Out:
# array(['B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'M'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)*100
# Out:
# 97.6608187134503

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[113   2]
#  [  2  54]]
#               precision    recall  f1-score   support
#
#            B       0.98      0.98      0.98       115
#            M       0.96      0.96      0.96        56
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# **naive** **bayes**

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array(['B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'M'], dtype='<U1')

# %%
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test,y_pred)
ac*100
# Out:
# 96.49122807017544

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[112   3]
#  [  3  53]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.97      0.97       115
#            M       0.95      0.95      0.95        56
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# **svm**

# %%
from sklearn.svm import SVC
svm_classifier = SVC(C=5.0, kernel = 'sigmoid')
print("SVM Classifier: \n", svm_classifier,"\n")
# Out:
# SVM Classifier:
#  SVC(C=5.0, kernel='sigmoid')

# %%
svm_classifier.fit(x_train, y_train)
# Out:
# SVC(C=5.0, kernel='sigmoid')

# %%
svm_train_predictions = svm_classifier.predict(x_train)
print("Predictions: \n", svm_train_predictions)
# Out:
# Predictions:
#  ['B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M'
#  'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'B'
#  'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B'
#  'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B'
#  'M' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B' 'M' 'M' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B'
#  'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M'
#  'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B'
#  'M' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'B'
#  'M' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B'
# ...

# %%
training_accuracy = svm_classifier.score(x_train, y_train)
print("Classifier Accuracy:: ", training_accuracy*100, "\n")
# Out:
# Classifier Accuracy::  93.71859296482413

# %%
training_accuracy*100
# Out:
# 93.71859296482413

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[112   3]
#  [  3  53]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.97      0.97       115
#            M       0.95      0.95      0.95        56
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# **Random** **Forest**

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier

regressor = RandomForestClassifier(n_estimators=20, random_state=0)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)*100
# Out:
# 96.49122807017544

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[112   3]
#  [  3  53]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.97      0.97       115
#            M       0.95      0.95      0.95        56
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# **Decision** **Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100,
max_depth = 3, min_samples_leaf = 5)


clf_entropy.fit(x_train, y_train)

y_pred = clf_entropy.predict(x_test)
print("Predicted values:")
print(y_pred)
# Out:
# Predicted values:
# ['B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B'
#  'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'M'
#  'M' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'M' 'B' 'M'
#  'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M'
#  'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M']

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 94.15204678362574

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[108   7]
#  [  3  53]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.94      0.96       115
#            M       0.88      0.95      0.91        56
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.93       171
# weighted avg       0.94      0.94      0.94       171
